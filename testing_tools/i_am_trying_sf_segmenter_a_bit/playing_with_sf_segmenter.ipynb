# %%
# !pip install pretty_midi
# !pip install numpy
# !pip install matplotlib
# !pip install msaf
# !pip install soundfile

# %%
# !pip install --upgrade pip
# !pip install --upgrade setuptools wheel

# %%
# !pip install sf_segmenter

# %%
# !brew install ffmpeg libsndfile
# Out:
# ==> Downloading https://formulae.brew.sh/api/formula.jws.json
# ######################################################################### 100.0%
# ==> Downloading https://formulae.brew.sh/api/cask.jws.json
# ######################################################################### 100.0%
# Warning: libsndfile 1.2.2 is already installed and up-to-date.
# To reinstall 1.2.2, run:
#   brew reinstall libsndfile
# ==> Downloading https://ghcr.io/v2/homebrew/core/ffmpeg/manifests/7.0.1
# ######################################################################### 100.0%
# ==> Fetching dependencies for ffmpeg: brotli, giflib, highway, imath, jpeg-turbo, libpng, lz4, zstd, libtiff, little-cms2, openexr, webp, jpeg-xl, libvmaf, aom, aribb24, dav1d, freetype, fontconfig, frei0r, libunistring, libidn2, libtasn1, nettle, p11-kit, libevent, libnghttp2, unbound, gnutls, xorgproto, libxau, libxdmcp, libxcb, libx11, libxext, libxrender, lzo, pixman, cairo, graphite2, icu4c, harfbuzz, fribidi, libunibreak, libass, libbluray, cjson, libmicrohttpd, mbedtls, librist, libsoxr, libssh, libvidstab, libvpx, opencore-amr, openjpeg, rav1e, libsamplerate, rubberband, sdl2, snappy, speex, srt, svt-av1, leptonica, libb2, libarchive, pango, tesseract, theora, x264, x265, xvid, libsodium, zeromq and zimg
# ==> Downloading https://ghcr.io/v2/homebrew/core/brotli/manifests/1.1.0-1
# ######################################################################### 100.0%
# ==> Fetching brotli
# ==> Downloading https://ghcr.io/v2/homebrew/core/brotli/blobs/sha256:2a95140d611
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/giflib/manifests/5.2.2
# ######################################################################### 100.0%
# ==> Fetching giflib
# ==> Downloading https://ghcr.io/v2/homebrew/core/giflib/blobs/sha256:c6b05aecad0
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/highway/manifests/1.2.0
# ######################################################################### 100.0%
# ==> Fetching highway
# ==> Downloading https://ghcr.io/v2/homebrew/core/highway/blobs/sha256:406c96cf28
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/imath/manifests/3.1.11
# ######################################################################### 100.0%
# ==> Fetching imath
# ==> Downloading https://ghcr.io/v2/homebrew/core/imath/blobs/sha256:9cffec79d68d
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/jpeg-turbo/manifests/3.0.3
# ######################################################################### 100.0%
# ==> Fetching jpeg-turbo
# ==> Downloading https://ghcr.io/v2/homebrew/core/jpeg-turbo/blobs/sha256:9ea4229
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libpng/manifests/1.6.43
# ######################################################################### 100.0%
# ==> Fetching libpng
# ==> Downloading https://ghcr.io/v2/homebrew/core/libpng/blobs/sha256:37936ba5cd5
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/lz4/manifests/1.9.4
# ######################################################################### 100.0%
# ==> Fetching lz4
# ==> Downloading https://ghcr.io/v2/homebrew/core/lz4/blobs/sha256:5a8b7116d978e4
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/zstd/manifests/1.5.6
# ######################################################################### 100.0%
# ==> Fetching zstd
# ==> Downloading https://ghcr.io/v2/homebrew/core/zstd/blobs/sha256:2028141683f55
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libtiff/manifests/4.6.0
# ######################################################################### 100.0%
# ==> Fetching libtiff
# ==> Downloading https://ghcr.io/v2/homebrew/core/libtiff/blobs/sha256:a9cafbce08
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/little-cms2/manifests/2.16
# ######################################################################### 100.0%
# ==> Fetching little-cms2
# ==> Downloading https://ghcr.io/v2/homebrew/core/little-cms2/blobs/sha256:d1ed57
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/openexr/manifests/3.2.4
# ######################################################################### 100.0%
# ==> Fetching openexr
# ==> Downloading https://ghcr.io/v2/homebrew/core/openexr/blobs/sha256:49b4acf727
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/webp/manifests/1.4.0
# ######################################################################### 100.0%
# ==> Fetching webp
# ==> Downloading https://ghcr.io/v2/homebrew/core/webp/blobs/sha256:1ba924051fcd6
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/jpeg-xl/manifests/0.10.2-1
# ######################################################################### 100.0%
# ==> Fetching jpeg-xl
# ==> Downloading https://ghcr.io/v2/homebrew/core/jpeg-xl/blobs/sha256:436eb06c81
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libvmaf/manifests/3.0.0
# ######################################################################### 100.0%
# ==> Fetching libvmaf
# ==> Downloading https://ghcr.io/v2/homebrew/core/libvmaf/blobs/sha256:bdc90ebc17
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/aom/manifests/3.9.1
# ######################################################################### 100.0%
# ==> Fetching aom
# ==> Downloading https://ghcr.io/v2/homebrew/core/aom/blobs/sha256:8cb9a41dca274a
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/aribb24/manifests/1.0.4
# ######################################################################### 100.0%
# ==> Fetching aribb24
# ==> Downloading https://ghcr.io/v2/homebrew/core/aribb24/blobs/sha256:00fe805d46
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/dav1d/manifests/1.4.3
# ######################################################################### 100.0%
# ==> Fetching dav1d
# ==> Downloading https://ghcr.io/v2/homebrew/core/dav1d/blobs/sha256:a8796b7771db
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/freetype/manifests/2.13.2-1
# ######################################################################### 100.0%
# ==> Fetching freetype
# ==> Downloading https://ghcr.io/v2/homebrew/core/freetype/blobs/sha256:8966d4448
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/fontconfig/manifests/2.15.0
# ######################################################################### 100.0%
# ==> Fetching fontconfig
# ==> Downloading https://ghcr.io/v2/homebrew/core/fontconfig/blobs/sha256:4732e8c
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/frei0r/manifests/2.3.3
# ######################################################################### 100.0%
# ==> Fetching frei0r
# ==> Downloading https://ghcr.io/v2/homebrew/core/frei0r/blobs/sha256:59d88950f34
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libunistring/manifests/1.2
# ######################################################################### 100.0%
# ==> Fetching libunistring
# ==> Downloading https://ghcr.io/v2/homebrew/core/libunistring/blobs/sha256:4a1c0
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libidn2/manifests/2.3.7
# ######################################################################### 100.0%
# ==> Fetching libidn2
# ==> Downloading https://ghcr.io/v2/homebrew/core/libidn2/blobs/sha256:670f6ed376
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libtasn1/manifests/4.19.0
# ######################################################################### 100.0%
# ==> Fetching libtasn1
# ==> Downloading https://ghcr.io/v2/homebrew/core/libtasn1/blobs/sha256:975eaba8f
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/nettle/manifests/3.10
# ######################################################################### 100.0%
# ==> Fetching nettle
# ==> Downloading https://ghcr.io/v2/homebrew/core/nettle/blobs/sha256:79f26a53dfc
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/p11-kit/manifests/0.25.3
# ######################################################################### 100.0%
# ==> Fetching p11-kit
# ==> Downloading https://ghcr.io/v2/homebrew/core/p11-kit/blobs/sha256:cd5ef135c5
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libevent/manifests/2.1.12_1
# ######################################################################### 100.0%
# ==> Fetching libevent
# ==> Downloading https://ghcr.io/v2/homebrew/core/libevent/blobs/sha256:38a3eb351
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libnghttp2/manifests/1.61.0
# ######################################################################### 100.0%
# ==> Fetching libnghttp2
# ==> Downloading https://ghcr.io/v2/homebrew/core/libnghttp2/blobs/sha256:6bd6cd9
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/unbound/manifests/1.20.0
# ######################################################################### 100.0%
# ==> Fetching unbound
# ==> Downloading https://ghcr.io/v2/homebrew/core/unbound/blobs/sha256:d747e30c1d
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/gnutls/manifests/3.8.4
# ######################################################################### 100.0%
# ==> Fetching gnutls
# ==> Downloading https://ghcr.io/v2/homebrew/core/gnutls/blobs/sha256:46373a7206c
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/xorgproto/manifests/2024.1
# ######################################################################### 100.0%
# ==> Fetching xorgproto
# ==> Downloading https://ghcr.io/v2/homebrew/core/xorgproto/blobs/sha256:3307601f
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libxau/manifests/1.0.11
# ######################################################################### 100.0%
# ==> Fetching libxau
# ==> Downloading https://ghcr.io/v2/homebrew/core/libxau/blobs/sha256:5af5678065c
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libxdmcp/manifests/1.1.5
# ######################################################################### 100.0%
# ==> Fetching libxdmcp
# ==> Downloading https://ghcr.io/v2/homebrew/core/libxdmcp/blobs/sha256:789326aa8
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libxcb/manifests/1.17.0
# ######################################################################### 100.0%
# ==> Fetching libxcb
# ==> Downloading https://ghcr.io/v2/homebrew/core/libxcb/blobs/sha256:73d10366172
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libx11/manifests/1.8.9
# ######################################################################### 100.0%
# ==> Fetching libx11
# ==> Downloading https://ghcr.io/v2/homebrew/core/libx11/blobs/sha256:f9f790ea819
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libxext/manifests/1.3.6
# ######################################################################### 100.0%
# ==> Fetching libxext
# ==> Downloading https://ghcr.io/v2/homebrew/core/libxext/blobs/sha256:50a9b29c59
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libxrender/manifests/0.9.11
# ######################################################################### 100.0%
# ==> Fetching libxrender
# ==> Downloading https://ghcr.io/v2/homebrew/core/libxrender/blobs/sha256:3872611
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/lzo/manifests/2.10
# ######################################################################### 100.0%
# ==> Fetching lzo
# ==> Downloading https://ghcr.io/v2/homebrew/core/lzo/blobs/sha256:167749edd2052e
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/pixman/manifests/0.42.2-1
# ######################################################################### 100.0%
# ==> Fetching pixman
# ==> Downloading https://ghcr.io/v2/homebrew/core/pixman/blobs/sha256:d355a294d3f
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/cairo/manifests/1.18.0
# ######################################################################### 100.0%
# ==> Fetching cairo
# ==> Downloading https://ghcr.io/v2/homebrew/core/cairo/blobs/sha256:06c6aaadeca8
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/graphite2/manifests/1.3.14
# ######################################################################### 100.0%
# ==> Fetching graphite2
# ==> Downloading https://ghcr.io/v2/homebrew/core/graphite2/blobs/sha256:4cdee055
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/icu4c/manifests/74.2
# ######################################################################### 100.0%
# ==> Fetching icu4c
# ==> Downloading https://ghcr.io/v2/homebrew/core/icu4c/blobs/sha256:3facc22a7821
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/harfbuzz/manifests/8.5.0
# ######################################################################### 100.0%
# ==> Fetching harfbuzz
# ==> Downloading https://ghcr.io/v2/homebrew/core/harfbuzz/blobs/sha256:27ef5184c
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/fribidi/manifests/1.0.15
# ######################################################################### 100.0%
# ==> Fetching fribidi
# ==> Downloading https://ghcr.io/v2/homebrew/core/fribidi/blobs/sha256:b952c91e6e
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libunibreak/manifests/6.1
# ######################################################################### 100.0%
# ==> Fetching libunibreak
# ==> Downloading https://ghcr.io/v2/homebrew/core/libunibreak/blobs/sha256:687db5
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libass/manifests/0.17.2
# ######################################################################### 100.0%
# ==> Fetching libass
# ==> Downloading https://ghcr.io/v2/homebrew/core/libass/blobs/sha256:87d9fe5a36c
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libbluray/manifests/1.3.4
# ######################################################################### 100.0%
# ==> Fetching libbluray
# ==> Downloading https://ghcr.io/v2/homebrew/core/libbluray/blobs/sha256:385b5460
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/cjson/manifests/1.7.18
# ######################################################################### 100.0%
# ==> Fetching cjson
# ==> Downloading https://ghcr.io/v2/homebrew/core/cjson/blobs/sha256:6deee0399f8b
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libmicrohttpd/manifests/1.0.1
# ######################################################################### 100.0%
# ==> Fetching libmicrohttpd
# ==> Downloading https://ghcr.io/v2/homebrew/core/libmicrohttpd/blobs/sha256:a787
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/mbedtls/manifests/3.6.0
# ######################################################################### 100.0%
# ==> Fetching mbedtls
# ==> Downloading https://ghcr.io/v2/homebrew/core/mbedtls/blobs/sha256:22f2f5791b
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/librist/manifests/0.2.10_1
# ######################################################################### 100.0%
# ==> Fetching librist
# ==> Downloading https://ghcr.io/v2/homebrew/core/librist/blobs/sha256:a008dc6bce
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libsoxr/manifests/0.1.3-1
# ######################################################################### 100.0%
# ==> Fetching libsoxr
# ==> Downloading https://ghcr.io/v2/homebrew/core/libsoxr/blobs/sha256:baddfdda71
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libssh/manifests/0.10.6
# ######################################################################### 100.0%
# ==> Fetching libssh
# ==> Downloading https://ghcr.io/v2/homebrew/core/libssh/blobs/sha256:f46550586ee
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libvidstab/manifests/1.1.1
# ######################################################################### 100.0%
# ==> Fetching libvidstab
# ==> Downloading https://ghcr.io/v2/homebrew/core/libvidstab/blobs/sha256:f006d60
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libvpx/manifests/1.13.1
# ######################################################################### 100.0%
# ==> Fetching libvpx
# ==> Downloading https://ghcr.io/v2/homebrew/core/libvpx/blobs/sha256:484698903af
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/opencore-amr/manifests/0.1.6
# ######################################################################### 100.0%
# ==> Fetching opencore-amr
# ==> Downloading https://ghcr.io/v2/homebrew/core/opencore-amr/blobs/sha256:b9598
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/openjpeg/manifests/2.5.2
# ######################################################################### 100.0%
# ==> Fetching openjpeg
# ==> Downloading https://ghcr.io/v2/homebrew/core/openjpeg/blobs/sha256:eef55952d
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/rav1e/manifests/0.7.1
# ######################################################################### 100.0%
# ==> Fetching rav1e
# ==> Downloading https://ghcr.io/v2/homebrew/core/rav1e/blobs/sha256:03c3c20f83de
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libsamplerate/manifests/0.2.2
# ######################################################################### 100.0%
# ==> Fetching libsamplerate
# ==> Downloading https://ghcr.io/v2/homebrew/core/libsamplerate/blobs/sha256:dc27
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/rubberband/manifests/3.3.0
# ######################################################################### 100.0%
# ==> Fetching rubberband
# ==> Downloading https://ghcr.io/v2/homebrew/core/rubberband/blobs/sha256:83e5b2a
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/sdl2/manifests/2.30.4
# ######################################################################### 100.0%
# ==> Fetching sdl2
# ==> Downloading https://ghcr.io/v2/homebrew/core/sdl2/blobs/sha256:7dd957c4ee6db
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/snappy/manifests/1.2.1
# ######################################################################### 100.0%
# ==> Fetching snappy
# ==> Downloading https://ghcr.io/v2/homebrew/core/snappy/blobs/sha256:2b905dfed7d
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/speex/manifests/1.2.1
# ######################################################################### 100.0%
# ==> Fetching speex
# ==> Downloading https://ghcr.io/v2/homebrew/core/speex/blobs/sha256:8dcf1981467a
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/srt/manifests/1.5.3
# ######################################################################### 100.0%
# ==> Fetching srt
# ==> Downloading https://ghcr.io/v2/homebrew/core/srt/blobs/sha256:b77e98814ca5b9
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/svt-av1/manifests/2.1.0
# ######################################################################### 100.0%
# ==> Fetching svt-av1
# ==> Downloading https://ghcr.io/v2/homebrew/core/svt-av1/blobs/sha256:b843eacec8
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/leptonica/manifests/1.84.1
# ######################################################################### 100.0%
# ==> Fetching leptonica
# ==> Downloading https://ghcr.io/v2/homebrew/core/leptonica/blobs/sha256:67fe34fb
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libb2/manifests/0.98.1
# ######################################################################### 100.0%
# ==> Fetching libb2
# ==> Downloading https://ghcr.io/v2/homebrew/core/libb2/blobs/sha256:52cef2730b35
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libarchive/manifests/3.7.4
# ######################################################################### 100.0%
# ==> Fetching libarchive
# ==> Downloading https://ghcr.io/v2/homebrew/core/libarchive/blobs/sha256:d97e0d2
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/pango/manifests/1.54.0
# ######################################################################### 100.0%
# ==> Fetching pango
# ==> Downloading https://ghcr.io/v2/homebrew/core/pango/blobs/sha256:c47cf2f24449
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/tesseract/manifests/5.4.1
# ######################################################################### 100.0%
# ==> Fetching tesseract
# ==> Downloading https://ghcr.io/v2/homebrew/core/tesseract/blobs/sha256:41f0427b
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/theora/manifests/1.1.1-4
# ######################################################################### 100.0%
# ==> Fetching theora
# ==> Downloading https://ghcr.io/v2/homebrew/core/theora/blobs/sha256:7f57dbcd0a1
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/x264/manifests/r3108
# ######################################################################### 100.0%
# ==> Fetching x264
# ==> Downloading https://ghcr.io/v2/homebrew/core/x264/blobs/sha256:19910a7d28752
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/x265/manifests/3.6
# ######################################################################### 100.0%
# ==> Fetching x265
# ==> Downloading https://ghcr.io/v2/homebrew/core/x265/blobs/sha256:ab1b898217941
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/xvid/manifests/1.3.7
# ######################################################################### 100.0%
# ==> Fetching xvid
# ==> Downloading https://ghcr.io/v2/homebrew/core/xvid/blobs/sha256:8062840ad8e79
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libsodium/manifests/1.0.20
# ######################################################################### 100.0%
# ==> Fetching libsodium
# ==> Downloading https://ghcr.io/v2/homebrew/core/libsodium/blobs/sha256:66835fcd
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/zeromq/manifests/4.3.5_1
# ######################################################################### 100.0%
# ==> Fetching zeromq
# ==> Downloading https://ghcr.io/v2/homebrew/core/zeromq/blobs/sha256:3bf8942ece9
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/zimg/manifests/3.0.5
# ######################################################################### 100.0%
# ==> Fetching zimg
# ==> Downloading https://ghcr.io/v2/homebrew/core/zimg/blobs/sha256:1a08f06a0a7fc
# ######################################################################### 100.0%
# ==> Fetching ffmpeg
# ==> Downloading https://ghcr.io/v2/homebrew/core/ffmpeg/blobs/sha256:06ad4d7e044
# ######################################################################### 100.0%
# ==> Installing dependencies for ffmpeg: brotli, giflib, highway, imath, jpeg-turbo, libpng, lz4, zstd, libtiff, little-cms2, openexr, webp, jpeg-xl, libvmaf, aom, aribb24, dav1d, freetype, fontconfig, frei0r, libunistring, libidn2, libtasn1, nettle, p11-kit, libevent, libnghttp2, unbound, gnutls, xorgproto, libxau, libxdmcp, libxcb, libx11, libxext, libxrender, lzo, pixman, cairo, graphite2, icu4c, harfbuzz, fribidi, libunibreak, libass, libbluray, cjson, libmicrohttpd, mbedtls, librist, libsoxr, libssh, libvidstab, libvpx, opencore-amr, openjpeg, rav1e, libsamplerate, rubberband, sdl2, snappy, speex, srt, svt-av1, leptonica, libb2, libarchive, pango, tesseract, theora, x264, x265, xvid, libsodium, zeromq and zimg
# ==> Installing ffmpeg dependency: brotli
# ==> Downloading https://ghcr.io/v2/homebrew/core/brotli/manifests/1.1.0-1
# Already downloaded: /Users/serdegsenere/Library/Caches/Homebrew/downloads/565098509cdfa90593ec9a41b41239f073843f88caed60ddaa3e6194ac4defda--brotli-1.1.0-1.bottle_manifest.json
# ==> Pouring brotli--1.1.0.arm64_sonoma.bottle.1.tar.gz
# 🍺  /opt/homebrew/Cellar/brotli/1.1.0: 25 files, 1016.0KB
# ==> Installing ffmpeg dependency: giflib
# ==> Downloading https://ghcr.io/v2/homebrew/core/giflib/manifests/5.2.2
# Already downloaded: /Users/serdegsenere/Library/Caches/Homebrew/downloads/283773c4d2db4fe867419d7eea6811a6417889d78fad8871041c07f49b22d2a1--giflib-5.2.2.bottle_manifest.json
# ==> Pouring giflib--5.2.2.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/giflib/5.2.2: 20 files, 547KB
# ==> Installing ffmpeg dependency: highway
# ==> Downloading https://ghcr.io/v2/homebrew/core/highway/manifests/1.2.0
# Already downloaded: /Users/serdegsenere/Library/Caches/Homebrew/downloads/8cb1608f21fba449c4e34b0a4912e3d73b6f2fa2577c916720799b5057207452--highway-1.2.0.bottle_manifest.json
# ==> Pouring highway--1.2.0.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/highway/1.2.0: 75 files, 4.2MB
# ==> Installing ffmpeg dependency: imath
# ==> Downloading https://ghcr.io/v2/homebrew/core/imath/manifests/3.1.11
# Already downloaded: /Users/serdegsenere/Library/Caches/Homebrew/downloads/4738c3b3aeed35cc9103ddfda8626c334457672a7e704d000247ccc8f1fddee9--imath-3.1.11.bottle_manifest.json
# ==> Pouring imath--3.1.11.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/imath/3.1.11: 50 files, 943.1KB
# ==> Installing ffmpeg dependency: jpeg-turbo
# ==> Downloading https://ghcr.io/v2/homebrew/core/jpeg-turbo/manifests/3.0.3
# Already downloaded: /Users/serdegsenere/Library/Caches/Homebrew/downloads/d6b83c0ba8addc9c21ec2cf9fc969e5754261e7cf808fdf5925816b927875bb1--jpeg-turbo-3.0.3.bottle_manifest.json
# ==> Pouring jpeg-turbo--3.0.3.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/jpeg-turbo/3.0.3: 45 files, 3.4MB
# ==> Installing ffmpeg dependency: libpng
# ==> Downloading https://ghcr.io/v2/homebrew/core/libpng/manifests/1.6.43
# Already downloaded: /Users/serdegsenere/Library/Caches/Homebrew/downloads/dd618b09b8d6d4b89203b771528951e5309631cc3afd8dc1236f0e98965f2b67--libpng-1.6.43.bottle_manifest.json
# ==> Pouring libpng--1.6.43.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/libpng/1.6.43: 28 files, 1.3MB
# ==> Installing ffmpeg dependency: lz4
# ==> Downloading https://ghcr.io/v2/homebrew/core/lz4/manifests/1.9.4
# Already downloaded: /Users/serdegsenere/Library/Caches/Homebrew/downloads/379e59b981667f9585b33a2ff318769d8edca3ce6fd2e9a67ed291ae3e0cc872--lz4-1.9.4.bottle_manifest.json
# ==> Pouring lz4--1.9.4.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/lz4/1.9.4: 23 files, 638.5KB
# ==> Installing ffmpeg dependency: zstd
# ==> Downloading https://ghcr.io/v2/homebrew/core/zstd/manifests/1.5.6
# Already downloaded: /Users/serdegsenere/Library/Caches/Homebrew/downloads/29403e0df5404d8aeca0e750ac135ec9ef44fc5eeb6df69170ed602acabf0ffb--zstd-1.5.6.bottle_manifest.json
# ==> Pouring zstd--1.5.6.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/zstd/1.5.6: 32 files, 2.2MB
# ==> Installing ffmpeg dependency: libtiff
# ==> Downloading https://ghcr.io/v2/homebrew/core/libtiff/manifests/4.6.0
# Already downloaded: /Users/serdegsenere/Library/Caches/Homebrew/downloads/9c8455a2f6bcea7bf3e3461218fba309141b0b0553b6e1afc5fe64e63caccff3--libtiff-4.6.0.bottle_manifest.json
# ==> Pouring libtiff--4.6.0.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/libtiff/4.6.0: 415 files, 6.7MB
# ==> Installing ffmpeg dependency: little-cms2
# ==> Downloading https://ghcr.io/v2/homebrew/core/little-cms2/manifests/2.16
# Already downloaded: /Users/serdegsenere/Library/Caches/Homebrew/downloads/c4e2b31b0daade62da1f3c2e57d69f74987bac35310011b87220145fa60b3558--little-cms2-2.16.bottle_manifest.json
# ==> Pouring little-cms2--2.16.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/little-cms2/2.16: 23 files, 1.4MB
# ==> Installing ffmpeg dependency: openexr
# ==> Downloading https://ghcr.io/v2/homebrew/core/openexr/manifests/3.2.4
# Already downloaded: /Users/serdegsenere/Library/Caches/Homebrew/downloads/64b203875dbfc58a68a1ab1bee0b9dcfa77a93c55c283a295b618ea0434c8060--openexr-3.2.4.bottle_manifest.json
# ==> Pouring openexr--3.2.4.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/openexr/3.2.4: 206 files, 8.0MB
# ==> Installing ffmpeg dependency: webp
# ==> Downloading https://ghcr.io/v2/homebrew/core/webp/manifests/1.4.0
# Already downloaded: /Users/serdegsenere/Library/Caches/Homebrew/downloads/4fd3ea2923bb7885c84ba3eee4738315675acd20fdff772153a63d8087daa4ad--webp-1.4.0.bottle_manifest.json
# ==> Pouring webp--1.4.0.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/webp/1.4.0: 64 files, 2.5MB
# ==> Installing ffmpeg dependency: jpeg-xl
# ==> Downloading https://ghcr.io/v2/homebrew/core/jpeg-xl/manifests/0.10.2-1
# Already downloaded: /Users/serdegsenere/Library/Caches/Homebrew/downloads/02b6819c94f2ead268c2b34c715bd82695a40cc3028c0c96f4e97509b58c3f0d--jpeg-xl-0.10.2-1.bottle_manifest.json
# ==> Pouring jpeg-xl--0.10.2.arm64_sonoma.bottle.1.tar.gz
# 🍺  /opt/homebrew/Cellar/jpeg-xl/0.10.2: 63 files, 28.3MB
# ==> Installing ffmpeg dependency: libvmaf
# ==> Downloading https://ghcr.io/v2/homebrew/core/libvmaf/manifests/3.0.0
# Already downloaded: /Users/serdegsenere/Library/Caches/Homebrew/downloads/6bf89f1d683f34ff5b4c58275236e1f038d5d8189e538795d9af83e07d4c8404--libvmaf-3.0.0.bottle_manifest.json
# ==> Pouring libvmaf--3.0.0.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/libvmaf/3.0.0: 235 files, 7.2MB
# ==> Installing ffmpeg dependency: aom
# ==> Downloading https://ghcr.io/v2/homebrew/core/aom/manifests/3.9.1
# Already downloaded: /Users/serdegsenere/Library/Caches/Homebrew/downloads/42dbe5f4422a19256563083479e5f427b220a06a6c6c4e5511a4961dd9d7ef72--aom-3.9.1.bottle_manifest.json
# ==> Pouring aom--3.9.1.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/aom/3.9.1: 24 files, 10MB
# ==> Installing ffmpeg dependency: aribb24
# ==> Downloading https://ghcr.io/v2/homebrew/core/aribb24/manifests/1.0.4
# Already downloaded: /Users/serdegsenere/Library/Caches/Homebrew/downloads/60185994f1623d662ea1959234838b47c2b4b891760a6b2af42d1cd3b36f2c0f--aribb24-1.0.4.bottle_manifest.json
# ==> Pouring aribb24--1.0.4.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/aribb24/1.0.4: 15 files, 223.6KB
# ==> Installing ffmpeg dependency: dav1d
# ==> Downloading https://ghcr.io/v2/homebrew/core/dav1d/manifests/1.4.3
# Already downloaded: /Users/serdegsenere/Library/Caches/Homebrew/downloads/11ff4584140441a10486e707a1cb2c691076f56c1f7497a4bf93baed51924a8c--dav1d-1.4.3.bottle_manifest.json
# ==> Pouring dav1d--1.4.3.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/dav1d/1.4.3: 16 files, 944.8KB
# ==> Installing ffmpeg dependency: freetype
# ==> Downloading https://ghcr.io/v2/homebrew/core/freetype/manifests/2.13.2-1
# Already downloaded: /Users/serdegsenere/Library/Caches/Homebrew/downloads/8d6ca45fa8766fb544a5e6dbc76f0a68568656ab4fe1e837704491bb24e3035d--freetype-2.13.2-1.bottle_manifest.json
# ==> Pouring freetype--2.13.2.arm64_sonoma.bottle.1.tar.gz
# 🍺  /opt/homebrew/Cellar/freetype/2.13.2: 68 files, 2.4MB
# ==> Installing ffmpeg dependency: fontconfig
# ==> Downloading https://ghcr.io/v2/homebrew/core/fontconfig/manifests/2.15.0
# Already downloaded: /Users/serdegsenere/Library/Caches/Homebrew/downloads/33d176010dc9a105404ed23b6c0f8b853bf3a2df2e274876d412d7229a643320--fontconfig-2.15.0.bottle_manifest.json
# ==> Pouring fontconfig--2.15.0.arm64_sonoma.bottle.tar.gz
# ==> Regenerating font cache, this may take a while
# ==> /opt/homebrew/Cellar/fontconfig/2.15.0/bin/fc-cache -frv
# 🍺  /opt/homebrew/Cellar/fontconfig/2.15.0: 91 files, 2.4MB
# ==> Installing ffmpeg dependency: frei0r
# ==> Downloading https://ghcr.io/v2/homebrew/core/frei0r/manifests/2.3.3
# Already downloaded: /Users/serdegsenere/Library/Caches/Homebrew/downloads/f9266f5e6cb521cdce245d9ea3bf63ef75e12bea0ab3a45f107cbe0d01f58c60--frei0r-2.3.3.bottle_manifest.json
# ==> Pouring frei0r--2.3.3.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/frei0r/2.3.3: 157 files, 5.6MB
# ==> Installing ffmpeg dependency: libunistring
# ==> Downloading https://ghcr.io/v2/homebrew/core/libunistring/manifests/1.2
# Already downloaded: /Users/serdegsenere/Library/Caches/Homebrew/downloads/48ac60445a77a63996cf15f6414f68a620d544fb683031b14eb3aea95c3064f6--libunistring-1.2.bottle_manifest.json
# ==> Pouring libunistring--1.2.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/libunistring/1.2: 60 files, 5MB
# ==> Installing ffmpeg dependency: libidn2
# ==> Downloading https://ghcr.io/v2/homebrew/core/libidn2/manifests/2.3.7
# Already downloaded: /Users/serdegsenere/Library/Caches/Homebrew/downloads/45d1d4d2930c4782bf53e761a1c0166cd8a40f4193ac8c44e86f0b6708e80354--libidn2-2.3.7.bottle_manifest.json
# ==> Pouring libidn2--2.3.7.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/libidn2/2.3.7: 81 files, 1MB
# ==> Installing ffmpeg dependency: libtasn1
# ==> Downloading https://ghcr.io/v2/homebrew/core/libtasn1/manifests/4.19.0
# Already downloaded: /Users/serdegsenere/Library/Caches/Homebrew/downloads/8abecce04f40738bc8a6921a6b96d847ea5c9759185d4bd9c7c9b5fb4922c375--libtasn1-4.19.0.bottle_manifest.json
# ==> Pouring libtasn1--4.19.0.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/libtasn1/4.19.0: 62 files, 720.8KB
# ==> Installing ffmpeg dependency: nettle
# ==> Downloading https://ghcr.io/v2/homebrew/core/nettle/manifests/3.10
# Already downloaded: /Users/serdegsenere/Library/Caches/Homebrew/downloads/8dc57e1a111535116cedad68fea09cf7a5477e6a1e357cdbb65b679768548586--nettle-3.10.bottle_manifest.json
# ==> Pouring nettle--3.10.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/nettle/3.10: 96 files, 2.7MB
# ==> Installing ffmpeg dependency: p11-kit
# ==> Downloading https://ghcr.io/v2/homebrew/core/p11-kit/manifests/0.25.3
# Already downloaded: /Users/serdegsenere/Library/Caches/Homebrew/downloads/cc547bf2f72da03680090015f5b720aff280ce33de9c33783a69c24fe97a4246--p11-kit-0.25.3.bottle_manifest.json
# ==> Pouring p11-kit--0.25.3.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/p11-kit/0.25.3: 29 files, 4.2MB
# ==> Installing ffmpeg dependency: libevent
# ==> Downloading https://ghcr.io/v2/homebrew/core/libevent/manifests/2.1.12_1
# Already downloaded: /Users/serdegsenere/Library/Caches/Homebrew/downloads/68b113f9ab63db45f4e1860de522ce2ca4fa081eb3c0d5c7d6005a35c3cf8d06--libevent-2.1.12_1.bottle_manifest.json
# ==> Pouring libevent--2.1.12_1.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/libevent/2.1.12_1: 58 files, 2.2MB
# ==> Installing ffmpeg dependency: libnghttp2
# ==> Downloading https://ghcr.io/v2/homebrew/core/libnghttp2/manifests/1.61.0
# Already downloaded: /Users/serdegsenere/Library/Caches/Homebrew/downloads/84e039765210f9da314a9b989360b06406c6123f9aae7b1a47dd010504d3bcfb--libnghttp2-1.61.0.bottle_manifest.json
# ==> Pouring libnghttp2--1.61.0.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/libnghttp2/1.61.0: 14 files, 807.3KB
# ==> Installing ffmpeg dependency: unbound
# ==> Downloading https://ghcr.io/v2/homebrew/core/unbound/manifests/1.20.0
# Already downloaded: /Users/serdegsenere/Library/Caches/Homebrew/downloads/b6115eae88cf2fb43cc96bb18cae0bbf698c522e211266e9e1f799add409f234--unbound-1.20.0.bottle_manifest.json
# ==> Pouring unbound--1.20.0.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/unbound/1.20.0: 59 files, 5.9MB
# ==> Installing ffmpeg dependency: gnutls
# ==> Downloading https://ghcr.io/v2/homebrew/core/gnutls/manifests/3.8.4
# Already downloaded: /Users/serdegsenere/Library/Caches/Homebrew/downloads/73c18cc76ca68c25efa04b897881358a5ad032ae8e54f9c5fe81b70875128236--gnutls-3.8.4.bottle_manifest.json
# ==> Pouring gnutls--3.8.4.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/gnutls/3.8.4: 1,293 files, 10.8MB
# ==> Installing ffmpeg dependency: xorgproto
# ==> Downloading https://ghcr.io/v2/homebrew/core/xorgproto/manifests/2024.1
# Already downloaded: /Users/serdegsenere/Library/Caches/Homebrew/downloads/d89d69340366d1d015e7214520f64081e2d82d7955fb28c6ea5f6539dcb610b2--xorgproto-2024.1.bottle_manifest.json
# ==> Pouring xorgproto--2024.1.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/xorgproto/2024.1: 268 files, 3.9MB
# ==> Installing ffmpeg dependency: libxau
# ==> Downloading https://ghcr.io/v2/homebrew/core/libxau/manifests/1.0.11
# Already downloaded: /Users/serdegsenere/Library/Caches/Homebrew/downloads/7faff26297b2e07682655beaa529cff7b3de0ad1abc013863ca3d03602b79ee7--libxau-1.0.11.bottle_manifest.json
# ==> Pouring libxau--1.0.11.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/libxau/1.0.11: 22 files, 127.1KB
# ==> Installing ffmpeg dependency: libxdmcp
# ==> Downloading https://ghcr.io/v2/homebrew/core/libxdmcp/manifests/1.1.5
# Already downloaded: /Users/serdegsenere/Library/Caches/Homebrew/downloads/8713e53f73d0be64780dbea522b0ee07027e6cc7828ff1a4fa0a6596f14cfe25--libxdmcp-1.1.5.bottle_manifest.json
# ==> Pouring libxdmcp--1.1.5.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/libxdmcp/1.1.5: 12 files, 140.0KB
# ==> Installing ffmpeg dependency: libxcb
# ==> Downloading https://ghcr.io/v2/homebrew/core/libxcb/manifests/1.17.0
# Already downloaded: /Users/serdegsenere/Library/Caches/Homebrew/downloads/90067be44989a7a337e7fa793989a66b6f8bfc1edfc82925162cab273ee94879--libxcb-1.17.0.bottle_manifest.json
# ==> Pouring libxcb--1.17.0.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/libxcb/1.17.0: 2,498 files, 7.5MB
# ==> Installing ffmpeg dependency: libx11
# ==> Downloading https://ghcr.io/v2/homebrew/core/libx11/manifests/1.8.9
# Already downloaded: /Users/serdegsenere/Library/Caches/Homebrew/downloads/ca292424919f76deb4667ed9445ade03489260780e6a18b3683e112aea943130--libx11-1.8.9.bottle_manifest.json
# ==> Pouring libx11--1.8.9.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/libx11/1.8.9: 1,043 files, 7.0MB
# ==> Installing ffmpeg dependency: libxext
# ==> Downloading https://ghcr.io/v2/homebrew/core/libxext/manifests/1.3.6
# Already downloaded: /Users/serdegsenere/Library/Caches/Homebrew/downloads/fedb843acbfcf682fb451396914bfc096f9ea2748376d4c43ce2af7ce1b766b7--libxext-1.3.6.bottle_manifest.json
# ==> Pouring libxext--1.3.6.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/libxext/1.3.6: 88 files, 458.4KB
# ==> Installing ffmpeg dependency: libxrender
# ==> Downloading https://ghcr.io/v2/homebrew/core/libxrender/manifests/0.9.11
# Already downloaded: /Users/serdegsenere/Library/Caches/Homebrew/downloads/134c11be8346a1b116e04983c2da6366f29c4f4c2abc17604dcdb80d0475ae9d--libxrender-0.9.11.bottle_manifest.json
# ==> Pouring libxrender--0.9.11.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/libxrender/0.9.11: 13 files, 221.8KB
# ==> Installing ffmpeg dependency: lzo
# ==> Downloading https://ghcr.io/v2/homebrew/core/lzo/manifests/2.10
# Already downloaded: /Users/serdegsenere/Library/Caches/Homebrew/downloads/d4aa5b0c239912c53bc857d1012c6b7feb4acb509618f5e100f95bf8521f08e7--lzo-2.10.bottle_manifest.json
# ==> Pouring lzo--2.10.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/lzo/2.10: 32 files, 568KB
# ==> Installing ffmpeg dependency: pixman
# ==> Downloading https://ghcr.io/v2/homebrew/core/pixman/manifests/0.42.2-1
# Already downloaded: /Users/serdegsenere/Library/Caches/Homebrew/downloads/2b0d8f2c63712ce503fa54309b732051a7ca5cd31bd561aa4aaba331bf26bcef--pixman-0.42.2-1.bottle_manifest.json
# ==> Pouring pixman--0.42.2.arm64_sonoma.bottle.1.tar.gz
# 🍺  /opt/homebrew/Cellar/pixman/0.42.2: 12 files, 1.3MB
# ==> Installing ffmpeg dependency: cairo
# ==> Downloading https://ghcr.io/v2/homebrew/core/cairo/manifests/1.18.0
# Already downloaded: /Users/serdegsenere/Library/Caches/Homebrew/downloads/1b8b7f19e38cb0e029497dfe0ad3f3557f605025c5575bdfe86c17b889c6e6d1--cairo-1.18.0.bottle_manifest.json
# ==> Pouring cairo--1.18.0.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/cairo/1.18.0: 53 files, 2.2MB
# ==> Installing ffmpeg dependency: graphite2
# ==> Downloading https://ghcr.io/v2/homebrew/core/graphite2/manifests/1.3.14
# Already downloaded: /Users/serdegsenere/Library/Caches/Homebrew/downloads/bbb4dd2ef1846301d1eb08053e19e11ca9c780f93f4d3b2d638fd94a9bf54a0c--graphite2-1.3.14.bottle_manifest.json
# ==> Pouring graphite2--1.3.14.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/graphite2/1.3.14: 19 files, 284.6KB
# ==> Installing ffmpeg dependency: icu4c
# ==> Downloading https://ghcr.io/v2/homebrew/core/icu4c/manifests/74.2
# Already downloaded: /Users/serdegsenere/Library/Caches/Homebrew/downloads/3e5230e726e5548db28bc0cf75710d6405903b742f941113d3dbe7483fad72a4--icu4c-74.2.bottle_manifest.json
# ==> Pouring icu4c--74.2.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/icu4c/74.2: 271 files, 77.9MB
# ==> Installing ffmpeg dependency: harfbuzz
# ==> Downloading https://ghcr.io/v2/homebrew/core/harfbuzz/manifests/8.5.0
# Already downloaded: /Users/serdegsenere/Library/Caches/Homebrew/downloads/3a4d22064fd474a301c7c45c5856ce7ad0d93b8ec485ec842972eab8ede343d3--harfbuzz-8.5.0.bottle_manifest.json
# ==> Pouring harfbuzz--8.5.0.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/harfbuzz/8.5.0: 77 files, 9.7MB
# ==> Installing ffmpeg dependency: fribidi
# ==> Downloading https://ghcr.io/v2/homebrew/core/fribidi/manifests/1.0.15
# Already downloaded: /Users/serdegsenere/Library/Caches/Homebrew/downloads/c743b3178050604a607c1ebc433b1b187bb5250afa047857b62467fb9f62249a--fribidi-1.0.15.bottle_manifest.json
# ==> Pouring fribidi--1.0.15.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/fribidi/1.0.15: 68 files, 740KB
# ==> Installing ffmpeg dependency: libunibreak
# ==> Downloading https://ghcr.io/v2/homebrew/core/libunibreak/manifests/6.1
# Already downloaded: /Users/serdegsenere/Library/Caches/Homebrew/downloads/0ce1b2ced7836a56fa520c73ee31abcb81d0433729fe597e94ef03dd9d8a89f8--libunibreak-6.1.bottle_manifest.json
# ==> Pouring libunibreak--6.1.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/libunibreak/6.1: 19 files, 336.9KB
# ==> Installing ffmpeg dependency: libass
# ==> Downloading https://ghcr.io/v2/homebrew/core/libass/manifests/0.17.2
# Already downloaded: /Users/serdegsenere/Library/Caches/Homebrew/downloads/f2f4136b66f851818232e0a025267eea0a9ecc64d03868a57a5ff4add0a96a16--libass-0.17.2.bottle_manifest.json
# ==> Pouring libass--0.17.2.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/libass/0.17.2: 12 files, 1011.1KB
# ==> Installing ffmpeg dependency: libbluray
# ==> Downloading https://ghcr.io/v2/homebrew/core/libbluray/manifests/1.3.4
# Already downloaded: /Users/serdegsenere/Library/Caches/Homebrew/downloads/3ca2a7bc181ca21ac727ad165abb77758d74c9c260dd155b33f741b1eee5801a--libbluray-1.3.4.bottle_manifest.json
# ==> Pouring libbluray--1.3.4.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/libbluray/1.3.4: 22 files, 1MB
# ==> Installing ffmpeg dependency: cjson
# ==> Downloading https://ghcr.io/v2/homebrew/core/cjson/manifests/1.7.18
# Already downloaded: /Users/serdegsenere/Library/Caches/Homebrew/downloads/3284084a143535a014f36b2aa7c948c6a28417940feba238b9425e4715e26a2b--cjson-1.7.18.bottle_manifest.json
# ==> Pouring cjson--1.7.18.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/cjson/1.7.18: 24 files, 257.3KB
# ==> Installing ffmpeg dependency: libmicrohttpd
# ==> Downloading https://ghcr.io/v2/homebrew/core/libmicrohttpd/manifests/1.0.1
# Already downloaded: /Users/serdegsenere/Library/Caches/Homebrew/downloads/01cc839b4ae42fa110aac833bd4c4ea38e803b45edd8f86da3d92d2f48922661--libmicrohttpd-1.0.1.bottle_manifest.json
# ==> Pouring libmicrohttpd--1.0.1.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/libmicrohttpd/1.0.1: 26 files, 1.5MB
# ==> Installing ffmpeg dependency: mbedtls
# ==> Downloading https://ghcr.io/v2/homebrew/core/mbedtls/manifests/3.6.0
# Already downloaded: /Users/serdegsenere/Library/Caches/Homebrew/downloads/2325275bc24f60ceb6e1de80d77b60d38eaf83bf0f445eb125aa0ad7f29ce681--mbedtls-3.6.0.bottle_manifest.json
# ==> Pouring mbedtls--3.6.0.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/mbedtls/3.6.0: 199 files, 13.2MB
# ==> Installing ffmpeg dependency: librist
# ==> Downloading https://ghcr.io/v2/homebrew/core/librist/manifests/0.2.10_1
# Already downloaded: /Users/serdegsenere/Library/Caches/Homebrew/downloads/c454114652985f2071c8c39a89669e3ded2ea81fee99e041ba5536c975f2d06f--librist-0.2.10_1.bottle_manifest.json
# ==> Pouring librist--0.2.10_1.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/librist/0.2.10_1: 29 files, 813.9KB
# ==> Installing ffmpeg dependency: libsoxr
# ==> Downloading https://ghcr.io/v2/homebrew/core/libsoxr/manifests/0.1.3-1
# Already downloaded: /Users/serdegsenere/Library/Caches/Homebrew/downloads/f10988e95845131f890c95b52caea83e46332718a0787ff7b473f71e9ca6e536--libsoxr-0.1.3-1.bottle_manifest.json
# ==> Pouring libsoxr--0.1.3.arm64_sonoma.bottle.1.tar.gz
# 🍺  /opt/homebrew/Cellar/libsoxr/0.1.3: 30 files, 326.6KB
# ==> Installing ffmpeg dependency: libssh
# ==> Downloading https://ghcr.io/v2/homebrew/core/libssh/manifests/0.10.6
# Already downloaded: /Users/serdegsenere/Library/Caches/Homebrew/downloads/a4ff6d890d834da2f865bf30651aa0ed1423be8e2684d4586895f1d9c887449b--libssh-0.10.6.bottle_manifest.json
# ==> Pouring libssh--0.10.6.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/libssh/0.10.6: 24 files, 1.3MB
# ==> Installing ffmpeg dependency: libvidstab
# ==> Downloading https://ghcr.io/v2/homebrew/core/libvidstab/manifests/1.1.1
# Already downloaded: /Users/serdegsenere/Library/Caches/Homebrew/downloads/cd6a6b0bc36ba382104f583fa6d59418959b6719401628d655a236dfc580cd85--libvidstab-1.1.1.bottle_manifest.json
# ==> Pouring libvidstab--1.1.1.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/libvidstab/1.1.1: 26 files, 190.5KB
# ==> Installing ffmpeg dependency: libvpx
# ==> Downloading https://ghcr.io/v2/homebrew/core/libvpx/manifests/1.13.1
# Already downloaded: /Users/serdegsenere/Library/Caches/Homebrew/downloads/364b66ab6140cccfc918fb168a803232862da070aac567fbd6f6531c14125399--libvpx-1.13.1.bottle_manifest.json
# ==> Pouring libvpx--1.13.1.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/libvpx/1.13.1: 21 files, 3.7MB
# ==> Installing ffmpeg dependency: opencore-amr
# ==> Downloading https://ghcr.io/v2/homebrew/core/opencore-amr/manifests/0.1.6
# Already downloaded: /Users/serdegsenere/Library/Caches/Homebrew/downloads/e2036ba279d7fa8546fb4e263e4b1276b5a68551a70e99aca9863561b1039962--opencore-amr-0.1.6.bottle_manifest.json
# ==> Pouring opencore-amr--0.1.6.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/opencore-amr/0.1.6: 18 files, 660.6KB
# ==> Installing ffmpeg dependency: openjpeg
# ==> Downloading https://ghcr.io/v2/homebrew/core/openjpeg/manifests/2.5.2
# Already downloaded: /Users/serdegsenere/Library/Caches/Homebrew/downloads/aa191c3580781971a7ecfcc8c109ad1f70e33174c5714ff2640476560c91f532--openjpeg-2.5.2.bottle_manifest.json
# ==> Pouring openjpeg--2.5.2.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/openjpeg/2.5.2: 539 files, 14.0MB
# ==> Installing ffmpeg dependency: rav1e
# ==> Downloading https://ghcr.io/v2/homebrew/core/rav1e/manifests/0.7.1
# Already downloaded: /Users/serdegsenere/Library/Caches/Homebrew/downloads/ccafd526f73546dc53bb2cd7d3c8d0e392229423fbc6962740a67633d8b06443--rav1e-0.7.1.bottle_manifest.json
# ==> Pouring rav1e--0.7.1.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/rav1e/0.7.1: 15 files, 45.5MB
# ==> Installing ffmpeg dependency: libsamplerate
# ==> Downloading https://ghcr.io/v2/homebrew/core/libsamplerate/manifests/0.2.2
# Already downloaded: /Users/serdegsenere/Library/Caches/Homebrew/downloads/27dd59fa55dbebeb65e77b8d04f3b390a899a35dad23d3fd7a4f895b3f7fbfed--libsamplerate-0.2.2.bottle_manifest.json
# ==> Pouring libsamplerate--0.2.2.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/libsamplerate/0.2.2: 33 files, 3MB
# ==> Installing ffmpeg dependency: rubberband
# ==> Downloading https://ghcr.io/v2/homebrew/core/rubberband/manifests/3.3.0
# Already downloaded: /Users/serdegsenere/Library/Caches/Homebrew/downloads/d7b37a08cef72d7b9431b19abc4aaa4649642b6610ad91f39146347d2aaeb60a--rubberband-3.3.0.bottle_manifest.json
# ==> Pouring rubberband--3.3.0.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/rubberband/3.3.0: 14 files, 1.7MB
# ==> Installing ffmpeg dependency: sdl2
# ==> Downloading https://ghcr.io/v2/homebrew/core/sdl2/manifests/2.30.4
# Already downloaded: /Users/serdegsenere/Library/Caches/Homebrew/downloads/786920d96ccbaf0340d0c000af2387f8910fb95c30b3a1a37a55aab9ce5a506c--sdl2-2.30.4.bottle_manifest.json
# ==> Pouring sdl2--2.30.4.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/sdl2/2.30.4: 94 files, 6.5MB
# ==> Installing ffmpeg dependency: snappy
# ==> Downloading https://ghcr.io/v2/homebrew/core/snappy/manifests/1.2.1
# Already downloaded: /Users/serdegsenere/Library/Caches/Homebrew/downloads/b2e6bfcdbddf1d451a8dbbb6fc3c44a267b753ac1a889dbb0b9159bf31dacdd5--snappy-1.2.1.bottle_manifest.json
# ==> Pouring snappy--1.2.1.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/snappy/1.2.1: 19 files, 172.2KB
# ==> Installing ffmpeg dependency: speex
# ==> Downloading https://ghcr.io/v2/homebrew/core/speex/manifests/1.2.1
# Already downloaded: /Users/serdegsenere/Library/Caches/Homebrew/downloads/483f702af62f72259facb50d3d47cd0bb25c8f0fb887029d30051a8cef860be5--speex-1.2.1.bottle_manifest.json
# ==> Pouring speex--1.2.1.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/speex/1.2.1: 26 files, 858.5KB
# ==> Installing ffmpeg dependency: srt
# ==> Downloading https://ghcr.io/v2/homebrew/core/srt/manifests/1.5.3
# Already downloaded: /Users/serdegsenere/Library/Caches/Homebrew/downloads/2c05aec9137f6d962cdfb85d47cfb9eb89182384aeaa5c9395f2fa9fe619e346--srt-1.5.3.bottle_manifest.json
# ==> Pouring srt--1.5.3.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/srt/1.5.3: 21 files, 4.6MB
# ==> Installing ffmpeg dependency: svt-av1
# ==> Downloading https://ghcr.io/v2/homebrew/core/svt-av1/manifests/2.1.0
# Already downloaded: /Users/serdegsenere/Library/Caches/Homebrew/downloads/102ce42b51f332472df26974a74e07a0103554e3322fe75b20df24e23d06140d--svt-av1-2.1.0.bottle_manifest.json
# ==> Pouring svt-av1--2.1.0.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/svt-av1/2.1.0: 25 files, 4.2MB
# ==> Installing ffmpeg dependency: leptonica
# ==> Downloading https://ghcr.io/v2/homebrew/core/leptonica/manifests/1.84.1
# Already downloaded: /Users/serdegsenere/Library/Caches/Homebrew/downloads/dc88f036b102e560c7103a72d25bc9ac6cc15c37284c0a81cd30f4fc0281eaa9--leptonica-1.84.1.bottle_manifest.json
# ==> Pouring leptonica--1.84.1.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/leptonica/1.84.1: 57 files, 7.0MB
# ==> Installing ffmpeg dependency: libb2
# ==> Downloading https://ghcr.io/v2/homebrew/core/libb2/manifests/0.98.1
# Already downloaded: /Users/serdegsenere/Library/Caches/Homebrew/downloads/9bb23dca331f0d74876fa5c769113885b92af8a741a851cdfe99f6dfd420b12d--libb2-0.98.1.bottle_manifest.json
# ==> Pouring libb2--0.98.1.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/libb2/0.98.1: 9 files, 129KB
# ==> Installing ffmpeg dependency: libarchive
# ==> Downloading https://ghcr.io/v2/homebrew/core/libarchive/manifests/3.7.4
# Already downloaded: /Users/serdegsenere/Library/Caches/Homebrew/downloads/d761d79792a479404434ff8a92cd30a935fa95d4cb1aee534cc2aa3b9904aa61--libarchive-3.7.4.bottle_manifest.json
# ==> Pouring libarchive--3.7.4.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/libarchive/3.7.4: 65 files, 3.8MB
# ==> Installing ffmpeg dependency: pango
# ==> Downloading https://ghcr.io/v2/homebrew/core/pango/manifests/1.54.0
# Already downloaded: /Users/serdegsenere/Library/Caches/Homebrew/downloads/06c4532b8d175a9098d6a1c5b6b1d2b154b126fef30ddbb5b26791e86b8c9675--pango-1.54.0.bottle_manifest.json
# ==> Pouring pango--1.54.0.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/pango/1.54.0: 69 files, 3.4MB
# ==> Installing ffmpeg dependency: tesseract
# ==> Downloading https://ghcr.io/v2/homebrew/core/tesseract/manifests/5.4.1
# Already downloaded: /Users/serdegsenere/Library/Caches/Homebrew/downloads/90a14ece96dee96d869e7eb9be23351b2da94395dbf347f386a130f23cfe1ac8--tesseract-5.4.1.bottle_manifest.json
# ==> Pouring tesseract--5.4.1.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/tesseract/5.4.1: 75 files, 33MB
# ==> Installing ffmpeg dependency: theora
# ==> Downloading https://ghcr.io/v2/homebrew/core/theora/manifests/1.1.1-4
# Already downloaded: /Users/serdegsenere/Library/Caches/Homebrew/downloads/dbefdb4ba8626ac7d284e0da23aaeb705c37e0bfbe0c3c22f05fe5fbcadf10e4--theora-1.1.1-4.bottle_manifest.json
# ==> Pouring theora--1.1.1.arm64_sonoma.bottle.4.tar.gz
# 🍺  /opt/homebrew/Cellar/theora/1.1.1: 98 files, 2MB
# ==> Installing ffmpeg dependency: x264
# ==> Downloading https://ghcr.io/v2/homebrew/core/x264/manifests/r3108
# Already downloaded: /Users/serdegsenere/Library/Caches/Homebrew/downloads/8bf7841097db8a60b1789ab16ac7f9395fc5e484932ab958334695a83e804e68--x264-r3108.bottle_manifest.json
# ==> Pouring x264--r3108.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/x264/r3108: 12 files, 4.2MB
# ==> Installing ffmpeg dependency: x265
# ==> Downloading https://ghcr.io/v2/homebrew/core/x265/manifests/3.6
# Already downloaded: /Users/serdegsenere/Library/Caches/Homebrew/downloads/5cdbdbb9c55e93a197fffb6fa64a943ccb0adb16936f48267be3e08efe7a606e--x265-3.6.bottle_manifest.json
# ==> Pouring x265--3.6.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/x265/3.6: 12 files, 12MB
# ==> Installing ffmpeg dependency: xvid
# ==> Downloading https://ghcr.io/v2/homebrew/core/xvid/manifests/1.3.7
# Already downloaded: /Users/serdegsenere/Library/Caches/Homebrew/downloads/b5121b85b4f5dfe07f78abbcbe520ae4926d781af3342e318e588b62aba59fe0--xvid-1.3.7.bottle_manifest.json
# ==> Pouring xvid--1.3.7.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/xvid/1.3.7: 11 files, 1.2MB
# ==> Installing ffmpeg dependency: libsodium
# ==> Downloading https://ghcr.io/v2/homebrew/core/libsodium/manifests/1.0.20
# Already downloaded: /Users/serdegsenere/Library/Caches/Homebrew/downloads/a9a9a2e1207e214070682a14f6470fb686cbb6ba7c24c2c747c0ca0663f42557--libsodium-1.0.20.bottle_manifest.json
# ==> Pouring libsodium--1.0.20.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/libsodium/1.0.20: 78 files, 888.8KB
# ==> Installing ffmpeg dependency: zeromq
# ==> Downloading https://ghcr.io/v2/homebrew/core/zeromq/manifests/4.3.5_1
# Already downloaded: /Users/serdegsenere/Library/Caches/Homebrew/downloads/27b053a576863f2b2aa214070e5737e3a0ce0a073760d26c39902468274880b1--zeromq-4.3.5_1.bottle_manifest.json
# ==> Pouring zeromq--4.3.5_1.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/zeromq/4.3.5_1: 85 files, 6.2MB
# ==> Installing ffmpeg dependency: zimg
# ==> Downloading https://ghcr.io/v2/homebrew/core/zimg/manifests/3.0.5
# Already downloaded: /Users/serdegsenere/Library/Caches/Homebrew/downloads/f94d5d93fe440d14fe866ceb3ada13593ef4b17f58985ebb17ea4320168b65cd--zimg-3.0.5.bottle_manifest.json
# ==> Pouring zimg--3.0.5.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/zimg/3.0.5: 28 files, 1.1MB
# ==> Installing ffmpeg
# ==> Pouring ffmpeg--7.0.1.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/ffmpeg/7.0.1: 287 files, 51.8MB
# ==> Running `brew cleanup ffmpeg`...
# Disable this behaviour by setting HOMEBREW_NO_INSTALL_CLEANUP.
# Hide these hints with HOMEBREW_NO_ENV_HINTS (see `man brew`).

# %% [markdown]
# ## import the necessary libraries

# %%
# !pip install librosa miditoolkit
# Out:
# Collecting librosa
#   Using cached librosa-0.10.2.post1-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: miditoolkit in /Volumes/C/Algoritmi/SaMuGeD-Algoritmi-DrDreSamplerAI-2024/.venv/lib/python3.12/site-packages (1.0.1)
# Collecting audioread>=2.1.9 (from librosa)
#   Using cached audioread-3.0.1-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: numpy!=1.22.0,!=1.22.1,!=1.22.2,>=1.20.3 in /Volumes/C/Algoritmi/SaMuGeD-Algoritmi-DrDreSamplerAI-2024/.venv/lib/python3.12/site-packages (from librosa) (2.0.0)
# Collecting scipy>=1.2.0 (from librosa)
#   Downloading scipy-1.13.1-cp312-cp312-macosx_12_0_arm64.whl.metadata (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 1.2 MB/s eta 0:00:00a 0:00:01
# Collecting scikit-learn>=0.20.0 (from librosa)
#   Downloading scikit_learn-1.5.0-cp312-cp312-macosx_12_0_arm64.whl.metadata (11 kB)
# Collecting joblib>=0.14 (from librosa)
#   Using cached joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: decorator>=4.3.0 in /Volumes/C/Algoritmi/SaMuGeD-Algoritmi-DrDreSamplerAI-2024/.venv/lib/python3.12/site-packages (from librosa) (5.1.1)
# Collecting numba>=0.51.0 (from librosa)
#   Downloading numba-0.60.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (2.7 kB)
# Requirement already satisfied: soundfile>=0.12.1 in /Volumes/C/Algoritmi/SaMuGeD-Algoritmi-DrDreSamplerAI-2024/.venv/lib/python3.12/site-packages (from librosa) (0.12.1)
# Collecting pooch>=1.1 (from librosa)
#   Using cached pooch-1.8.2-py3-none-any.whl.metadata (10 kB)
# Collecting soxr>=0.3.2 (from librosa)
#   Downloading soxr-0.3.7-cp312-cp312-macosx_11_0_arm64.whl.metadata (5.5 kB)
# Collecting typing-extensions>=4.1.1 (from librosa)
#   Using cached typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# Collecting lazy-loader>=0.1 (from librosa)
#   Using cached lazy_loader-0.4-py3-none-any.whl.metadata (7.6 kB)
# Collecting msgpack>=1.0 (from librosa)
#   Downloading msgpack-1.0.8-cp312-cp312-macosx_11_0_arm64.whl.metadata (9.1 kB)
# Requirement already satisfied: matplotlib in /Volumes/C/Algoritmi/SaMuGeD-Algoritmi-DrDreSamplerAI-2024/.venv/lib/python3.12/site-packages (from miditoolkit) (3.9.0)
# Requirement already satisfied: mido>=1.1.16 in /Volumes/C/Algoritmi/SaMuGeD-Algoritmi-DrDreSamplerAI-2024/.venv/lib/python3.12/site-packages (from miditoolkit) (1.3.2)
# Requirement already satisfied: packaging in /Volumes/C/Algoritmi/SaMuGeD-Algoritmi-DrDreSamplerAI-2024/.venv/lib/python3.12/site-packages (from lazy-loader>=0.1->librosa) (23.2)
# Collecting llvmlite<0.44,>=0.43.0dev0 (from numba>=0.51.0->librosa)
#   Downloading llvmlite-0.43.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (4.8 kB)
# Requirement already satisfied: platformdirs>=2.5.0 in /Volumes/C/Algoritmi/SaMuGeD-Algoritmi-DrDreSamplerAI-2024/.venv/lib/python3.12/site-packages (from pooch>=1.1->librosa) (4.2.2)
# Collecting requests>=2.19.0 (from pooch>=1.1->librosa)
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn>=0.20.0->librosa)
#   Downloading threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: cffi>=1.0 in /Volumes/C/Algoritmi/SaMuGeD-Algoritmi-DrDreSamplerAI-2024/.venv/lib/python3.12/site-packages (from soundfile>=0.12.1->librosa) (1.16.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Volumes/C/Algoritmi/SaMuGeD-Algoritmi-DrDreSamplerAI-2024/.venv/lib/python3.12/site-packages (from matplotlib->miditoolkit) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /Volumes/C/Algoritmi/SaMuGeD-Algoritmi-DrDreSamplerAI-2024/.venv/lib/python3.12/site-packages (from matplotlib->miditoolkit) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Volumes/C/Algoritmi/SaMuGeD-Algoritmi-DrDreSamplerAI-2024/.venv/lib/python3.12/site-packages (from matplotlib->miditoolkit) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Volumes/C/Algoritmi/SaMuGeD-Algoritmi-DrDreSamplerAI-2024/.venv/lib/python3.12/site-packages (from matplotlib->miditoolkit) (1.4.5)
# Requirement already satisfied: pillow>=8 in /Volumes/C/Algoritmi/SaMuGeD-Algoritmi-DrDreSamplerAI-2024/.venv/lib/python3.12/site-packages (from matplotlib->miditoolkit) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Volumes/C/Algoritmi/SaMuGeD-Algoritmi-DrDreSamplerAI-2024/.venv/lib/python3.12/site-packages (from matplotlib->miditoolkit) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Volumes/C/Algoritmi/SaMuGeD-Algoritmi-DrDreSamplerAI-2024/.venv/lib/python3.12/site-packages (from matplotlib->miditoolkit) (2.9.0.post0)
# Requirement already satisfied: pycparser in /Volumes/C/Algoritmi/SaMuGeD-Algoritmi-DrDreSamplerAI-2024/.venv/lib/python3.12/site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.22)
# Requirement already satisfied: six>=1.5 in /Volumes/C/Algoritmi/SaMuGeD-Algoritmi-DrDreSamplerAI-2024/.venv/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib->miditoolkit) (1.16.0)
# Collecting charset-normalizer<4,>=2 (from requests>=2.19.0->pooch>=1.1->librosa)
#   Using cached charset_normalizer-3.3.2-cp312-cp312-macosx_11_0_arm64.whl.metadata (33 kB)
# Collecting idna<4,>=2.5 (from requests>=2.19.0->pooch>=1.1->librosa)
#   Using cached idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Collecting urllib3<3,>=1.21.1 (from requests>=2.19.0->pooch>=1.1->librosa)
#   Downloading urllib3-2.2.2-py3-none-any.whl.metadata (6.4 kB)
# Collecting certifi>=2017.4.17 (from requests>=2.19.0->pooch>=1.1->librosa)
#   Using cached certifi-2024.6.2-py3-none-any.whl.metadata (2.2 kB)
# Using cached librosa-0.10.2.post1-py3-none-any.whl (260 kB)
# Using cached audioread-3.0.1-py3-none-any.whl (23 kB)
# Using cached joblib-1.4.2-py3-none-any.whl (301 kB)
# Using cached lazy_loader-0.4-py3-none-any.whl (12 kB)
# Downloading msgpack-1.0.8-cp312-cp312-macosx_11_0_arm64.whl (85 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.4/85.4 kB 4.1 MB/s eta 0:00:00
# Downloading numba-0.60.0-cp312-cp312-macosx_11_0_arm64.whl (2.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 9.6 MB/s eta 0:00:00:00:0100:01
# Using cached pooch-1.8.2-py3-none-any.whl (64 kB)
# Downloading scikit_learn-1.5.0-cp312-cp312-macosx_12_0_arm64.whl (11.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.0/11.0 MB 12.0 MB/s eta 0:00:0000:0100:01
# Downloading scipy-1.13.1-cp312-cp312-macosx_12_0_arm64.whl (30.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.4/30.4 MB 12.0 MB/s eta 0:00:0000:0100:01
# Downloading soxr-0.3.7-cp312-cp312-macosx_11_0_arm64.whl (390 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 390.2/390.2 kB 11.0 MB/s eta 0:00:00
# Using cached typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Downloading llvmlite-0.43.0-cp312-cp312-macosx_11_0_arm64.whl (28.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 28.8/28.8 MB 13.4 MB/s eta 0:00:0000:0100:01
# Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Downloading threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Using cached certifi-2024.6.2-py3-none-any.whl (164 kB)
# Using cached charset_normalizer-3.3.2-cp312-cp312-macosx_11_0_arm64.whl (119 kB)
# Using cached idna-3.7-py3-none-any.whl (66 kB)
# Downloading urllib3-2.2.2-py3-none-any.whl (121 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.4/121.4 kB 6.8 MB/s eta 0:00:00
# Installing collected packages: urllib3, typing-extensions, threadpoolctl, soxr, scipy, msgpack, llvmlite, lazy-loader, joblib, idna, charset-normalizer, certifi, audioread, scikit-learn, requests, numba, pooch, librosa
# Successfully installed audioread-3.0.1 certifi-2024.6.2 charset-normalizer-3.3.2 idna-3.7 joblib-1.4.2 lazy-loader-0.4 librosa-0.10.2.post1 llvmlite-0.43.0 msgpack-1.0.8 numba-0.60.0 pooch-1.8.2 requests-2.32.3 scikit-learn-1.5.0 scipy-1.13.1 soxr-0.3.7 threadpoolctl-3.5.0 typing-extensions-4.12.2 urllib3-2.2.2

# %%
import mido
import numpy as np
import matplotlib.pyplot as plt
from sf_segmenter import Segmenter
import librosa

# load MIDI
midi_file = 'Take_On_Me.mid'
mid = mido.MidiFile(midi_file)

# %%
# basic information
print(f"Number of tracks: {len(mid.tracks)}")
print(f"Type: {mid.type}")
print(f"Length: {mid.length:.2f} seconds")

# note events
notes = []
for track in mid.tracks:
    time = 0
    for msg in track:
        time += msg.time
        if msg.type == 'note_on' and msg.velocity > 0:
            notes.append((time, msg.note, msg.velocity))
        elif msg.type == 'note_off' or (msg.type == 'note_on' and msg.velocity == 0):
            notes.append((time, msg.note, 0))

# convert to numpy array?
notes = np.array(notes)
# Out:
# Number of tracks: 14
# Type: 1
# Length: 226.29 seconds

# %%
# piano roll
ticks_per_beat = mid.ticks_per_beat
total_ticks = int(max(notes[:, 0]))
piano_roll = np.zeros((128, total_ticks))

for start, pitch, velocity in notes:
    start_tick = int(start)
    if start_tick < total_ticks:
        piano_roll[pitch, start_tick] = velocity

plt.figure(figsize=(12, 6))
plt.imshow(piano_roll, aspect='auto', origin='lower', cmap='hot', interpolation='nearest')
plt.colorbar(label='Velocity')
plt.title('Piano Roll Representation')
plt.xlabel('Time (ticks)')
plt.ylabel('MIDI Note Number')
plt.show()

# %%
# a simple self-similarity matrix
def compute_ssm(feature_sequence):
    n = feature_sequence.shape[1]
    ssm = np.zeros((n, n))
    for i in range(n):
        for j in range(n):
            ssm[i, j] = np.linalg.norm(feature_sequence[:, i] - feature_sequence[:, j])
    return ssm

# downsample piano roll for faster computation?
downsampled_roll = piano_roll[:, ::100]  

ssm = compute_ssm(downsampled_roll)

plt.figure(figsize=(10, 10))
plt.imshow(ssm, cmap='hot', origin='lower', interpolation='nearest')
plt.colorbar(label='Distance')
plt.title('Self-Similarity Matrix')
plt.xlabel('Time')
plt.ylabel('Time')
plt.show()

# %%
from scipy.signal import find_peaks

# Simple segmentation based on novelty curve
def compute_novelty_curve(ssm):
    kernel = np.eye(7)
    kernel[0, 0] = kernel[-1, -1] = 0.5
    novelty = np.zeros(ssm.shape[0])
    for i in range(3, ssm.shape[0] - 3):
        sub_ssm = ssm[i-3:i+4, i-3:i+4]
        novelty[i] = np.sum(sub_ssm * kernel)
    return novelty

novelty_curve = compute_novelty_curve(ssm)

# peaks in the novelty curve
peaks, _ = find_peaks(novelty_curve, distance=10, prominence=0.1)

# peak positions to seconds
seconds_per_frame = mid.length / ssm.shape[0]
peak_times = peaks * seconds_per_frame

print("Segment boundaries (seconds):", peak_times)

# novelty curve and detected boundaries
plt.figure(figsize=(12, 4))
plt.plot(novelty_curve)
plt.vlines(peaks, ymin=0, ymax=max(novelty_curve), color='r')
plt.title('Novelty Curve and Detected Boundaries')
plt.xlabel('Frame')
plt.ylabel('Novelty')
plt.show()
# Out:
# Segment boundaries (seconds): []
